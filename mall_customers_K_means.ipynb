# %% [markdown]
# <a href="https://colab.research.google.com/github/matheusfsm/Data-Science-Projects/blob/master/mall_customers_K_means.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importando pacotes
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
# caminho de download dos dados
data_path = 'https://leadfortaleza.com.br/ead2pcd/conteudo/tmp/myopenolat_1_102915131150883/aula/Mall_Customers.csv'

# %%
# criando um dataframe chamado 'df'
df = pd.read_csv(data_path)

# %%
# imprimindo cabeçalho
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# tamanho do dataframe
print("Tamanho do df: {}\n".format(df.shape))
# Out:
# Tamanho do df: (200, 5)

# %%
# verificando dados nulos
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
# resumo estatistico do df
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %% [markdown]
# ### Divisão do dataframe:

# %%
# 1. escolher e importar um modelo
from sklearn.cluster import KMeans

# 2. Instanciar e escolher os hyperparameters
model = KMeans(n_clusters=2)
model_2 = KMeans(n_clusters=5)

# 3. Separar os dados
X = df[['Age', 'Spending Score (1-100)']]

# 4. Fit do modelo (treinar)
model.fit(X)
model_2.fit(X)

# 5. Fazer previsões em cima de novos dados
y_pred = model.predict(X)
y_pred2 = model_2.predict(X)

# %%
# plotando grafico de disperção sem divisões
plt.scatter('Age', 'Spending Score (1-100)', data=df, s=40)
plt.title('Customer groups')
plt.xlabel('Age')
plt.ylabel('Score (1-100)')
plt.show()

# %% [markdown]
# ### Grafico com 2 grupos de clientes:

# %%
# plotando grafico com 2 grupos
plt.scatter('Age', 'Spending Score (1-100)', data=df, c=y_pred, s=40, cmap='viridis')
plt.title('Customer groups')
plt.xlabel('Age')
plt.ylabel('Score (1-100)')
plt.show()

# %% [markdown]
# ### Grafico com 5 grupos de clientes:

# %%
# plotando grafico com 5 grupos
plt.scatter('Age', 'Spending Score (1-100)', data=df, c=y_pred2, s=40, cmap='viridis')
plt.title('Customer groups')
plt.xlabel('Age')
plt.ylabel('Score (1-100)')
plt.show()
